# %%
import pandas as pd

# %%
col_name = ['user', 'bname', 'rate']
df01 = pd.read_csv('watchaFinal0213.csv', encoding = 'utf-8-sig', sep = '\t', header = None, names = col_name)

# %%
df01.tail()
# Out:
#              user            bname  rate
# 61946  unknown400              이방인   3.5
# 61947  unknown400               설국   4.0
# 61948  unknown400         그리스인 조르바   5.0
# 61949  unknown400             1984   5.0
# 61950  unknown400  참을 수 없는 존재의 가벼움   5.0

# %%
df02 = df01.pivot_table(index = ['user'], columns = ['bname'], \
                              values = 'rate', fill_value = 0, dropna =False)

# %%
df02
# Out:
# bname        맥스 테그마크의 라이프 3.0   은빛 피렌체 2 - 메디치가 살인사건    인류의 가장 위대한 모험 아폴로 8  \
# user
# encore01                    0                     0.0                     0
# encore02                    0                     0.0                     0
# encore03                    0                     0.0                     0
# encore04                    0                     0.0                     0
# encore05                    0                     0.0                     0
# encore06                    0                     0.0                     0
# encore08                    0                     0.0                     0
# encore09                    0                     0.0                     0
# encore10                    0                     0.0                     0
# encore11                    0                     0.0                     0
# encore12                    0                     0.0                     0
# ...
